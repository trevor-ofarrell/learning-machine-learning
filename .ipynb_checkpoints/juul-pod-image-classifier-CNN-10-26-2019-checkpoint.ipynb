# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import numpy as np
import pickle
import time

tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [1]
layer_sizes = [64]
conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes{}-dense{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()
                
            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer - 1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
                
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))
            
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])

            new_y = np.asarray(y, dtype=np.float32)

            model.fit(X, new_y, batch_size=5, epochs=15, validation_split=0.3, callbacks=[tensorboard])
            
model.save('64x3-CNN.model')
# Out:
# 3-conv-64-nodes1-dense1572085473
# Train on 229 samples, validate on 99 samples
# Epoch 1/15
# 229/229 [==============================] - 3s 15ms/sample - loss: 0.6641 - accuracy: 0.6332 - val_loss: 0.6240 - val_accuracy: 0.7273
# Epoch 2/15
# 229/229 [==============================] - 2s 8ms/sample - loss: 0.6226 - accuracy: 0.6769 - val_loss: 0.6064 - val_accuracy: 0.7273
# Epoch 3/15
# 229/229 [==============================] - 2s 8ms/sample - loss: 0.5778 - accuracy: 0.7074 - val_loss: 0.5039 - val_accuracy: 0.7677
# Epoch 4/15
# 229/229 [==============================] - 2s 9ms/sample - loss: 0.5054 - accuracy: 0.7511 - val_loss: 0.5315 - val_accuracy: 0.7172
# Epoch 5/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.4362 - accuracy: 0.7860 - val_loss: 0.6018 - val_accuracy: 0.7475
# Epoch 6/15
# 229/229 [==============================] - 3s 11ms/sample - loss: 0.3607 - accuracy: 0.8428 - val_loss: 0.5397 - val_accuracy: 0.7374
# Epoch 7/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.2905 - accuracy: 0.8559 - val_loss: 0.6920 - val_accuracy: 0.7273
# Epoch 8/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.2700 - accuracy: 0.8777 - val_loss: 0.6674 - val_accuracy: 0.7576
# Epoch 9/15
# 229/229 [==============================] - 2s 11ms/sample - loss: 0.2261 - accuracy: 0.8996 - val_loss: 0.8385 - val_accuracy: 0.7374
# Epoch 10/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.1672 - accuracy: 0.9214 - val_loss: 0.8562 - val_accuracy: 0.7475
# Epoch 11/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.1686 - accuracy: 0.9258 - val_loss: 0.9280 - val_accuracy: 0.7677
# Epoch 12/15
# 229/229 [==============================] - 2s 10ms/sample - loss: 0.1340 - accuracy: 0.9432 - val_loss: 0.8903 - val_accuracy: 0.7475
# Epoch 13/15
# 229/229 [==============================] - 3s 14ms/sample - loss: 0.0800 - accuracy: 0.9694 - val_loss: 1.1833 - val_accuracy: 0.7576
# Epoch 14/15
# 229/229 [==============================] - 3s 15ms/sample - loss: 0.0643 - accuracy: 0.9913 - val_loss: 1.3438 - val_accuracy: 0.7071
# Epoch 15/15
# 229/229 [==============================] - 3s 12ms/sample - loss: 0.0710 - accuracy: 0.9738 - val_loss: 1.0864 - val_accuracy: 0.7778
# INFO:tensorflow:Assets written to: 64x3-CNN.model/assets
