# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import matplotlib.pyplot as plt
import numpy as np
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0]
layer_sizes = [64]
conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes{}-dense{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()
                
            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer - 1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
                
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))
            
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])

            new_y = np.asarray(y, dtype=np.float32)
                      
            model.fit(X, new_y, batch_size=22, epochs=22, validation_split=0.3, callbacks=[tensorboard])
            
model.save('64x3-CNN.model')
# Out:
# 3-conv-64-nodes0-dense1572297689
# Train on 317 samples, validate on 137 samples
# Epoch 1/22
# 317/317 [==============================] - 4s 13ms/sample - loss: 0.6931 - accuracy: 0.5457 - val_loss: 0.6759 - val_accuracy: 0.6569
# Epoch 2/22
# 317/317 [==============================] - 4s 11ms/sample - loss: 0.6648 - accuracy: 0.6404 - val_loss: 0.6560 - val_accuracy: 0.5255
# Epoch 3/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.6229 - accuracy: 0.6562 - val_loss: 0.5770 - val_accuracy: 0.7080
# Epoch 4/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.5850 - accuracy: 0.6688 - val_loss: 0.5494 - val_accuracy: 0.7007
# Epoch 5/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.5551 - accuracy: 0.7287 - val_loss: 0.5855 - val_accuracy: 0.6715
# Epoch 6/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.5173 - accuracy: 0.7445 - val_loss: 0.5274 - val_accuracy: 0.7226
# Epoch 7/22
# 317/317 [==============================] - 4s 11ms/sample - loss: 0.5009 - accuracy: 0.7603 - val_loss: 0.5356 - val_accuracy: 0.7518
# Epoch 8/22
# 317/317 [==============================] - 4s 11ms/sample - loss: 0.4512 - accuracy: 0.7950 - val_loss: 0.5040 - val_accuracy: 0.7518
# Epoch 9/22
# 317/317 [==============================] - 4s 12ms/sample - loss: 0.4187 - accuracy: 0.8139 - val_loss: 0.4984 - val_accuracy: 0.7445
# Epoch 10/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.4006 - accuracy: 0.8328 - val_loss: 0.5345 - val_accuracy: 0.7518
# Epoch 11/22
# 317/317 [==============================] - 4s 12ms/sample - loss: 0.3689 - accuracy: 0.8549 - val_loss: 0.4983 - val_accuracy: 0.7956
# Epoch 12/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.3462 - accuracy: 0.8707 - val_loss: 0.5137 - val_accuracy: 0.7883
# Epoch 13/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.2891 - accuracy: 0.9054 - val_loss: 0.5368 - val_accuracy: 0.7518
# Epoch 14/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.2425 - accuracy: 0.9117 - val_loss: 0.5171 - val_accuracy: 0.7737
# Epoch 15/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.2853 - accuracy: 0.8833 - val_loss: 0.5411 - val_accuracy: 0.7737
# Epoch 16/22
# 317/317 [==============================] - 3s 11ms/sample - loss: 0.2276 - accuracy: 0.8864 - val_loss: 0.5498 - val_accuracy: 0.7956
# Epoch 17/22
# 317/317 [==============================] - 4s 12ms/sample - loss: 0.1667 - accuracy: 0.9495 - val_loss: 0.6854 - val_accuracy: 0.7664
# Epoch 18/22
# 317/317 [==============================] - 4s 12ms/sample - loss: 0.1422 - accuracy: 0.9748 - val_loss: 0.5974 - val_accuracy: 0.7883
# Epoch 19/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.1037 - accuracy: 0.9748 - val_loss: 0.6673 - val_accuracy: 0.8029
# Epoch 20/22
# 317/317 [==============================] - 4s 12ms/sample - loss: 0.1126 - accuracy: 0.9685 - val_loss: 0.9998 - val_accuracy: 0.6788
# Epoch 21/22
# 317/317 [==============================] - 3s 10ms/sample - loss: 0.1402 - accuracy: 0.9495 - val_loss: 0.7277 - val_accuracy: 0.7664
# Epoch 22/22
# 317/317 [==============================] - 3s 9ms/sample - loss: 0.0942 - accuracy: 0.9779 - val_loss: 0.6923 - val_accuracy: 0.7737
# INFO:tensorflow:Assets written to: 64x3-CNN.model/assets
