# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import matplotlib.pyplot as plt
import numpy as np
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0]
layer_sizes = [64]
conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes{}-dense{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()
                
            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer - 1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
                
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))
            
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])

            new_y = np.asarray(y, dtype=np.float32)
                      
            model.fit(X, new_y, batch_size=21, epochs=25, validation_split=0.3, callbacks=[tensorboard])
            
model.save('64x3-CNN.model')
# Out:
# 3-conv-64-nodes0-dense1572299123
# Train on 317 samples, validate on 137 samples
# Epoch 1/25
# 317/317 [==============================] - 6s 20ms/sample - loss: 0.7012 - accuracy: 0.4164 - val_loss: 0.6903 - val_accuracy: 0.5766
# Epoch 2/25
# 317/317 [==============================] - 6s 18ms/sample - loss: 0.6892 - accuracy: 0.5994 - val_loss: 0.6836 - val_accuracy: 0.6131
# Epoch 3/25
# 317/317 [==============================] - 6s 19ms/sample - loss: 0.6683 - accuracy: 0.6467 - val_loss: 0.6239 - val_accuracy: 0.6642
# Epoch 4/25
# 317/317 [==============================] - 6s 20ms/sample - loss: 0.6190 - accuracy: 0.7192 - val_loss: 0.5685 - val_accuracy: 0.7080
# Epoch 5/25
# 317/317 [==============================] - 7s 21ms/sample - loss: 0.5850 - accuracy: 0.7256 - val_loss: 0.5951 - val_accuracy: 0.6496
# Epoch 6/25
# 317/317 [==============================] - 7s 23ms/sample - loss: 0.5739 - accuracy: 0.7098 - val_loss: 0.5324 - val_accuracy: 0.7299
# Epoch 7/25
# 317/317 [==============================] - 6s 20ms/sample - loss: 0.5426 - accuracy: 0.7697 - val_loss: 0.5393 - val_accuracy: 0.7372
# Epoch 8/25
# 317/317 [==============================] - 8s 24ms/sample - loss: 0.5290 - accuracy: 0.7350 - val_loss: 0.6458 - val_accuracy: 0.6642
# Epoch 9/25
# 317/317 [==============================] - 7s 24ms/sample - loss: 0.4772 - accuracy: 0.7760 - val_loss: 0.5632 - val_accuracy: 0.7372
# Epoch 10/25
# 317/317 [==============================] - 8s 27ms/sample - loss: 0.4619 - accuracy: 0.7760 - val_loss: 0.4971 - val_accuracy: 0.7445
# Epoch 11/25
# 317/317 [==============================] - 7s 21ms/sample - loss: 0.4021 - accuracy: 0.8139 - val_loss: 0.4921 - val_accuracy: 0.7737
# Epoch 12/25
# 317/317 [==============================] - 6s 20ms/sample - loss: 0.3653 - accuracy: 0.8423 - val_loss: 0.5283 - val_accuracy: 0.7591
# Epoch 13/25
# 317/317 [==============================] - 7s 22ms/sample - loss: 0.3498 - accuracy: 0.8423 - val_loss: 0.6822 - val_accuracy: 0.6861
# Epoch 14/25
# 317/317 [==============================] - 7s 23ms/sample - loss: 0.4073 - accuracy: 0.8265 - val_loss: 0.6098 - val_accuracy: 0.7080
# Epoch 15/25
# 317/317 [==============================] - 7s 23ms/sample - loss: 0.2872 - accuracy: 0.8959 - val_loss: 0.6113 - val_accuracy: 0.7372
# Epoch 16/25
# 317/317 [==============================] - 7s 22ms/sample - loss: 0.2355 - accuracy: 0.9180 - val_loss: 0.7944 - val_accuracy: 0.7080
# Epoch 17/25
# 317/317 [==============================] - 7s 23ms/sample - loss: 0.1942 - accuracy: 0.9527 - val_loss: 0.7496 - val_accuracy: 0.7226
# Epoch 18/25
# 317/317 [==============================] - 7s 22ms/sample - loss: 0.1592 - accuracy: 0.9621 - val_loss: 0.7470 - val_accuracy: 0.7737
# Epoch 19/25
# 317/317 [==============================] - 8s 24ms/sample - loss: 0.1191 - accuracy: 0.9779 - val_loss: 0.8567 - val_accuracy: 0.7591
# Epoch 20/25
# 317/317 [==============================] - 8s 24ms/sample - loss: 0.0903 - accuracy: 0.9874 - val_loss: 0.8202 - val_accuracy: 0.7956
# Epoch 21/25
# 317/317 [==============================] - 7s 24ms/sample - loss: 0.1578 - accuracy: 0.9432 - val_loss: 0.9723 - val_accuracy: 0.7518
# Epoch 22/25
# 317/317 [==============================] - 7s 22ms/sample - loss: 0.0867 - accuracy: 0.9842 - val_loss: 1.1024 - val_accuracy: 0.7518
# Epoch 23/25
# 317/317 [==============================] - 8s 24ms/sample - loss: 0.0523 - accuracy: 0.9937 - val_loss: 0.9668 - val_accuracy: 0.7591
# Epoch 24/25
# 317/317 [==============================] - 7s 23ms/sample - loss: 0.0331 - accuracy: 0.9968 - val_loss: 1.0316 - val_accuracy: 0.7737
# Epoch 25/25
# 317/317 [==============================] - 8s 24ms/sample - loss: 0.0255 - accuracy: 0.9968 - val_loss: 1.1504 - val_accuracy: 0.7445
# INFO:tensorflow:Assets written to: 64x3-CNN.model/assets
